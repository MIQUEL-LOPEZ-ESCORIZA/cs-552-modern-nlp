# %% [markdown]
# # 📚 Exercise Session - Week 1
#
# Welcome to Week 1 exercise session of **CS-552: Modern NLP**!
#
# > **What will be covered:**
# > 1. [**TASK A:** Training a word embedding model](#1)
# > 2. [**TASK B:** Word embedding similarity](#2)
# > 3. [**TASK C:** Sentiment analysis of movie reviews](#3)
#
# > **By the end of the session you will be able to:**
# > - ✅  train from scratch a word embedding model
# > - ✅  load and use pre-trained word embeddings
# > - ✅  perform word embedding analogies and understand their implicit biases
# > - ✅  train and evaluate a sentiment classifier using word embeddings

# %% [markdown]
# ## Intro - Word embedding models
#
# #### 🔵 What?
# A word embedding is a learned representation for text where words that have the same meaning have a similar representation. It is this approach to representing words and documents that may be considered one of the key breakthroughs of deep learning on challenging natural language processing problems.
#
#
# #### 🟡 How?
# There are different versions of word embeddings depending on the way the embeddings are learned.
# - Some of the models learn a focus word given the neighboring words that surround them
# - Some other models learn the neighboring words given the focus word.
# - Some other word embedding models try to derive the relationship between the words from global statistics of the words in the overall corpus.
#
#
# #### 🟣 Why?
# Word embedding in NLP is an important concept that is used for representing words for text analysis in the form of real-valued vectors. It is an advancement in NLP that has improved the ability of computers to understand text-based content in a better way.
#
#
# #### A little bit of history on word embeddings
# In 2013, Tomas Mikolov et al. developed an algorithm for learning word embeddings called **Word2vec** [[paper](https://arxiv.org/abs/1301.3781)][[code](https://code.google.com/archive/p/word2vec/)]. This algorithm uses a shallow neural network to learn word vectors so that the representation of each word of a given corpus is good at predicting its own contexts (Skip-Gram) or vice versa (CBOW).
#
# One year after the publication of Word2vec, Pennington et al. developed a new algorithm for learning word embeddings called **GloVe** [[paper](https://nlp.stanford.edu/pubs/glove.pdf)][[code](https://github.com/stanfordnlp/GloVe)]. This algorithm is based on the observation that word relationships can be recovered from the co-occurrence statistics of any (large enough) corpus.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid orange;background-color:#F3F3F3;color:#424242;">
#     <h3>Goal of today's exercise</h3><br/>
# In this exercise session, we will use both variants of these word embedding models (Word2Vec and GloVe) for our experiments.
# For the first part, we will train from scratch a Word2vec model with different datasets. In the second part, we will load pre-trained Word2vec and GloVe embeddings and test them on how well they capture concept similarity among words. Finally, for the last part, we will train a simple sentiment analysis classifier with these pre-trained embeddings as we discussed in the lecture.
#
# You will need to fill in all the missing pieces of code. For each one, you will be given a 🎯 `Goal` guidance that explains the steps you need to implement and a 💻 `API` reference with the functions or classes you can use to achieve each goal.
#
# </div>

# %%
# !conda create -n "mnlp_exercises" python=3.10.11 --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 26.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises
#
#   added / updated specs:
#     - python=3.10.11
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h500dc9f_9         130 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     libffi-3.5.2               |       hd1f9c09_0          52 KB  conda-forge
#     liblzma-5.8.2              |       h11316ed_0         103 KB  conda-forge
#     liblzma-devel-5.8.2        |       h11316ed_0         115 KB  conda-forge
#     libsqlite-3.51.2           |       hb99441e_0         964 KB  conda-forge
#     openssl-3.6.1              |       hb6871ef_1         2.6 MB  conda-forge
#     packaging-26.0             |     pyhcf101f3_0          70 KB  conda-forge
#     pip-26.0.1                 |     pyh8b19718_0         1.1 MB  conda-forge
#     python-3.10.11             |he7542f4_0_cpython        12.4 MB  conda-forge
#     readline-8.3               |       h68b038d_0         310 KB  conda-forge
#     setuptools-82.0.0          |     pyh332efcf_0         623 KB  conda-forge
#     tk-8.6.13                  |       h7142dee_3         3.1 MB  conda-forge
#     tzdata-2025c               |       hc9c84f9_1         116 KB  conda-forge
#     wheel-0.46.3               |     pyhd8ed1ab_0          31 KB  conda-forge
#     xz-5.8.2                   |       h8df612c_0          23 KB  conda-forge
#     xz-gpl-tools-5.8.2         |       h8df612c_0          33 KB  conda-forge
#     xz-tools-5.8.2             |       h11316ed_0          84 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        22.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              conda-forge/osx-64::bzip2-1.0.8-h500dc9f_9
#   ca-certificates    conda-forge/noarch::ca-certificates-2026.1.4-hbd8a1cb_0
#   libffi             conda-forge/osx-64::libffi-3.5.2-hd1f9c09_0
#   liblzma            conda-forge/osx-64::liblzma-5.8.2-h11316ed_0
#   liblzma-devel      conda-forge/osx-64::liblzma-devel-5.8.2-h11316ed_0
#   libsqlite          conda-forge/osx-64::libsqlite-3.51.2-hb99441e_0
#   libzlib            conda-forge/osx-64::libzlib-1.3.1-hd23fc13_2
#   ncurses            conda-forge/osx-64::ncurses-6.5-h0622a9a_3
#   openssl            conda-forge/osx-64::openssl-3.6.1-hb6871ef_1
#   packaging          conda-forge/noarch::packaging-26.0-pyhcf101f3_0
#   pip                conda-forge/noarch::pip-26.0.1-pyh8b19718_0
#   python             conda-forge/osx-64::python-3.10.11-he7542f4_0_cpython
#   readline           conda-forge/osx-64::readline-8.3-h68b038d_0
#   setuptools         conda-forge/noarch::setuptools-82.0.0-pyh332efcf_0
#   tk                 conda-forge/osx-64::tk-8.6.13-h7142dee_3
#   tzdata             conda-forge/noarch::tzdata-2025c-hc9c84f9_1
#   wheel              conda-forge/noarch::wheel-0.46.3-pyhd8ed1ab_0
#   xz                 conda-forge/osx-64::xz-5.8.2-h8df612c_0
#   xz-gpl-tools       conda-forge/osx-64::xz-gpl-tools-5.8.2-h8df612c_0
#   xz-tools           conda-forge/osx-64::xz-tools-5.8.2-h11316ed_0
#
#
#
# Downloading and Extracting Packages
# xz-gpl-tools-5.8.2   | 33 KB     | ##################################### | 100%
# xz-5.8.2             | 23 KB     | ##################################### | 100%
# libsqlite-3.51.2     | 964 KB    | ##################################### | 100%
# setuptools-82.0.0    | 623 KB    | ##################################### | 100%
# pip-26.0.1           | 1.1 MB    | ##################################### | 100%
# liblzma-5.8.2        | 103 KB    | ##################################### | 100%
# tk-8.6.13            | 3.1 MB    | ##################################### | 100%
# python-3.10.11       | 12.4 MB   | ##################################### | 100%
# ca-certificates-2026 | 143 KB    | ##################################### | 100%
# wheel-0.46.3         | 31 KB     | ##################################### | 100%
# readline-8.3         | 310 KB    | ##################################### | 100%
# libffi-3.5.2         | 52 KB     | ##################################### | 100%
# liblzma-devel-5.8.2  | 115 KB    | ##################################### | 100%
# openssl-3.6.1        | 2.6 MB    | ##################################### | 100%
# xz-tools-5.8.2       | 84 KB     | ##################################### | 100%
# bzip2-1.0.8          | 130 KB    | ##################################### | 100%
# packaging-26.0       | 70 KB     | ##################################### | 100%
# tzdata-2025c         | 116 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate mnlp_exercises
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Retrieving notices: ...working... done

# %%
# !conda activate mnlp_exercises
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !pip install pandas gensim numpy matplotlib seaborn scikit-learn tqdm torch torchmetrics ipykernel
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (91 kB)
# Collecting gensim
#   Downloading gensim-4.4.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (8.5 kB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (11 kB)
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting torch
#   Using cached torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchmetrics
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: ipykernel in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (7.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.7.0 (from gensim)
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_x86_64.whl.metadata (61 kB)
# Collecting smart_open>=1.8.1 (from gensim)
#   Downloading smart_open-7.5.1-py3-none-any.whl.metadata (24 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp310-cp310-macosx_10_10_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.24.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from torch) (4.15.0)
# Collecting sympy (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: appnope>=0.1.2 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: decorator in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: exceptiongroup in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting wrapt (from smart_open>=1.8.1->gensim)
#   Downloading wrapt-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl.metadata (7.4 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Using cached markupsafe-3.0.3-cp310-cp310-macosx_10_9_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure_eval in /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading pandas-2.3.3-cp310-cp310-macosx_10_9_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 1.3 MB/s  0:00:08m0:00:0100:01
# Downloading gensim-4.4.0-cp310-cp310-macosx_10_9_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 1.3 MB/s  0:00:19m0:00:0100:01
# Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_x86_64.whl (6.9 MB)
# Downloading matplotlib-3.10.8-cp310-cp310-macosx_10_12_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 1.2 MB/s  0:00:06m0:00:0100:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scikit_learn-1.7.2-cp310-cp310-macosx_10_9_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 1.3 MB/s  0:00:07m0:00:0100:01
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Using cached torch-2.2.2-cp310-none-macosx_10_9_x86_64.whl (150.8 MB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 1.3 MB/s  0:00:00 eta 0:00:01
# Downloading contourpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (268 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp310-cp310-macosx_10_9_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 1.2 MB/s  0:00:01 eta 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.4.9-cp310-cp310-macosx_10_9_x86_64.whl (66 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading pillow-12.1.1-cp310-cp310-macosx_10_10_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 1.3 MB/s  0:00:04 eta 0:00:010m
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_x86_64.whl (25.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 1.3 MB/s  0:00:18m0:00:0100:01m
# Downloading smart_open-7.5.1-py3-none-any.whl (64 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading filelock-3.24.3-py3-none-any.whl (24 kB)
# Downloading fsspec-2026.2.0-py3-none-any.whl (202 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp310-cp310-macosx_10_9_x86_64.whl (11 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading wrapt-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl (60 kB)
# Installing collected packages: pytz, mpmath, wrapt, tzdata, tqdm, threadpoolctl, sympy, pyparsing, pillow, numpy, networkx, MarkupSafe, lightning-utilities, kiwisolver, joblib, fsspec, fonttools, filelock, cycler, smart_open, scipy, pandas, jinja2, contourpy, torch, scikit-learn, matplotlib, gensim, torchmetrics, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30/30 [seaborn]9/30 [seaborn]rics]
# Successfully installed MarkupSafe-3.0.3 contourpy-1.3.2 cycler-0.12.1 filelock-3.24.3 fonttools-4.61.1 fsspec-2026.2.0 gensim-4.4.0 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.4.9 lightning-utilities-0.15.3 matplotlib-3.10.8 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 pandas-2.3.3 pillow-12.1.1 pyparsing-3.3.2 pytz-2025.2 scikit-learn-1.7.2 scipy-1.15.3 seaborn-0.13.2 smart_open-7.5.1 sympy-1.14.0 threadpoolctl-3.6.0 torch-2.2.2 torchmetrics-1.8.2 tqdm-4.67.3 tzdata-2025.3 wrapt-2.1.1

# %%
# imported libraries for this exercise
import pandas as pd
import numpy as np
from gensim.test.utils import common_texts
from gensim.utils import tokenize   
from gensim.models import Word2Vec
import gensim.downloader
import torch 
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchmetrics.classification import BinaryAccuracy
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#     return await f(*args, **kwargs)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#     res = shell.run_cell(
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/x3/y_1dsmpd5zqfgzj1rdlj20m00000gn/T/ipykernel_56050/1809370931.py", line 8, in <module>
#     import torch
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/miquellopezescoriza/opt/anaconda3/envs/mnlp_exercises/lib/python3.10/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %% [markdown]
# <a name="1"></a>
# ## 1. TASK A: Training a word embedding model from stratch
#
# In this part, you will train a model to learn vector representations of words and more specifically, we will train the word2vec model.
# To train the model we will use the Gensim library which is a free open-source Python library for representing documents as semantic vectors.
#
# > **Gensim** is designed to process raw, unstructured digital texts (“plain text”) using unsupervised machine learning algorithms. The algorithms in Gensim, such as Word2Vec, FastText, Latent Semantic Indexing (LSI, LSA, LsiModel), Latent Dirichlet Allocation (LDA, LdaModel) etc, automatically discover the semantic structure of documents by examining statistical co-occurrence patterns within a corpus of training documents. These algorithms are unsupervised, which means no human input is necessary – you only need a corpus of plain text documents.
# >
# > You can discover all Gensim functionalities [here](https://radimrehurek.com/gensim/index.html).
#
# To train your embedding model, you will need to instantiate Word2Vec and pass the data to the model to train with. We essentially need to pass on a list of lists, where each list within the main list contains a set of tokens from a user review. Word2Vec uses all these tokens to internally create a vocabulary.
#
# **Data:** We will train our embedding model using a toy dataset that is provided by the Gensim library. You can use the dataset under the following path `gensim.test.utils.common_texts`.

# %%
# bag of words for each sentence in toy dataset (imported from the gensim library in cell 2)
common_texts
# Out:
# [['human', 'interface', 'computer'],
#  ['survey', 'user', 'computer', 'system', 'response', 'time'],
#  ['eps', 'user', 'interface', 'system'],
#  ['system', 'human', 'system', 'eps'],
#  ['user', 'response', 'time'],
#  ['trees'],
#  ['graph', 'trees'],
#  ['graph', 'minors', 'trees'],
#  ['graph', 'minors', 'survey']]

# %% [markdown]
# #### Train a Gensim Word2Vec model

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Train with `common_texts` dataset a Gensim word2vec model.<br>
#
# - 💻  **API:** You can use `gensim.models.Word2Vec` class.
# </div>

# %%
#instantiate and train model
# common_texts is a list of tokenized sentences
w2v_model = Word2Vec(
    sentences=common_texts,
    vector_size=100,
    window=5,
    min_count=1,
    workers=1,
    epochs=10
)

# %%
# dict with vocabulary key indexes
words = w2v_model.wv.key_to_index
words
# Out:
# {'system': 0,
#  'graph': 1,
#  'trees': 2,
#  'user': 3,
#  'minors': 4,
#  'eps': 5,
#  'time': 6,
#  'response': 7,
#  'survey': 8,
#  'computer': 9,
#  'interface': 10,
#  'human': 11}

# %% [markdown]
# #### Find word similarities

# %%
# explore embeddings
vector = w2v_model.wv['computer']  # get numpy vector of a word
print('The vector length of the word is {}.'.format(len(vector)))
# Out:
# The vector length of the word is 100.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Use the trained word2vec model to find most similar words for token _"computer"_.
# - 💻 **API:** You can use Gensim's `.most_similar` function.
#
# </div>

# %%
# print most similar words
print(w2v_model.wv.most_similar(positive=['computer'], topn=5))
# Out:
# [('system', 0.21617142856121063), ('survey', 0.04468921199440956), ('interface', 0.01537806261330843), ('time', 0.0020044848788529634), ('trees', -0.03284316509962082)]

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Play around with initial settings
#
# - Re-train the model with different datasets ( [Wikipedia](https://radimrehurek.com/gensim/corpora/wikicorpus.html), [Opinosis](https://radimrehurek.com/gensim/corpora/opinosiscorpus.html) ) and vector sizes and run similarity with different top-n. How would you comment on the results?
# - Think about the limitations of the Word2vec approach.
#
# </div>

# %% [markdown]
# ***--- YOU CAN WRITE YOU ANSWER HERE ---***
#
# ---

# %% [markdown]
# <a name="2"></a>
# ## 2. TASK B: Word embedding similarity
#
# For this task, we will use pre-trained word embedding models.
#
# **Word2Vec:** We will use once again Word2vec as in the previous question, but in this case we will load the pre-trained version of it that has been trained on a part of the Google News dataset (about 100 billion words). The model variant that we will use, contains 300-dimensional vectors for 3 million words and phrases.
#
# **GloVe:** We will also use GloVe word embeddings that have been pre-trained on 2B tweets, 27B tokens, 1.2M vocab, uncased. The model variant that we will use contains 100-dimensional vectors.
#
# Once we load the vector represenation of words, we will:
# - find similarities between group of words.
# - discover a very cool property of word embeddings through analogies.
# - evaluate their performance on how well they capture the semantics between words on the SimLex task.

# %% [markdown]
# ### 2.1 Using pre-trained word embedding models

# %%
# Show all available models in gensim-data
print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
# Download the "word2vec-google-news-300" embeddings
w2v_vectors = gensim.downloader.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# Download the "glove-wiki-gigaword-100" embeddings
glove_vectors = gensim.downloader.load('glove-wiki-gigaword-100')
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %% [markdown]
# The best way to understand a data is by visualizing them. We will use t-SNE to reduce the data with 300 dimensions to 2 dimensions, so that we can plot the data on our screens.
# t-SNE is a non-linear dimensionality reduction algorithm that attempts to represent high-dimensional data and the underlying relationships between vectors in a lower-dimensional space.

# %%
# visualization utility function. NO NEED TO CHANGE ANYTHING HERE
sns.set_style('whitegrid')
sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

def tsne_scatterplot(model, search_word, topn):
    labels = [search_word]
    tokens = [model[search_word]]
    similar = [1]
    close_words = model.similar_by_word(search_word, topn=topn)
    for word in close_words:
        tokens.append(model[word[0]])
        labels.append(word[0])
        similar.append(word[1])

    tsne_model = TSNE(n_components=2, perplexity=topn, init='pca')
    coordinates = tsne_model.fit_transform(np.array(tokens))
    df = pd.DataFrame({'x': [x for x in coordinates[:, 0]],
                       'y': [y for y in coordinates[:, 1]],
                       'words': labels,
                       'similarity': similar}
                      )
    fig, ax = plt.subplots()
    plot = ax.scatter(df.x, df.y, c=df.similarity, cmap='Reds')
    for i in range(len(df)):
        ax.annotate("  {} ({:.2f})".format(df.words[i].title(),
                                           df.similarity[i]),
                    (df.x[i], df.y[i]))

    plt.colorbar(mappable=plot, ax=ax)
    plt.title('t-SNE visualization for {}'.format(search_word))
    plt.show()

# %%
# visualize the most similar words for a given word.
tsne_scatterplot(glove_vectors, "computer", 20)

# %% [markdown]
# #### Interactive visualization
#
# In the following link, you can explore the state-of-the-art models in an interactive embedding visualization: https://projector.tensorflow.org/.
#
# Using the Embedding Projector, you can graphically represent high dimensional embeddings. This can be helpful in visualizing, examining, and understanding your embeddings.
#
# Give it a try! Test interesting clusters of similar words!

# %% [markdown]
# ### 2.2 Check word analogies
#
# The fact that we can analyze the use of words in language to deduce their meaning is a fundamental idea of [distributional semantics](https://en.wikipedia.org/wiki/Distributional_semantics). This is the inspiration behind many algorithms for learning numerical representations of words (word embeddings). An important aspect of these representations is the ability to solve word analogies of the form “A is to B what C is to X” using simple arithmetic. This is generally simplified as “King — Man + Woman $\sim$ Queen.
#
# In this subquestion we will explore interesting relations that can be extracted from word embeddings. You will be given semantic relations and you need to implement the respective code using the embedding model.

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Use the pre-trained GloVe embeddings to implement the following analogies.
# - 💻 **API:** You can use Gensim's `.most_similar` function.
#
# </div>

# %% [markdown]
# **Analogy A:**  `King` — `Man` + `Woman` ~ `?`
#
# `?`: `Queen`

# %%
# Check the "most similar words", using the default "cosine similarity" measure.
glove_vectors.most_similar(
    positive=['king', 'woman'],
    negative=['man'],
    topn=10
)
# Out:
# [('queen', 0.7698541283607483),
#  ('monarch', 0.6843380928039551),
#  ('throne', 0.6755736470222473),
#  ('daughter', 0.6594556570053101),
#  ('princess', 0.6520534157752991),
#  ('prince', 0.651703417301178),
#  ('elizabeth', 0.6464517712593079),
#  ('mother', 0.631171703338623),
#  ('emperor', 0.6106470823287964),
#  ('wife', 0.6098655462265015)]

# %% [markdown]
# **Analogy B:**  `France` — `Paris` + `Athens` ~ `?`
#
# `?`: `Greece`

# %%
glove_vectors.most_similar(
    positive=['france', 'athens'],
    negative=['paris'],
    topn=10
)
# Out:
# [('greece', 0.7968204617500305),
#  ('finland', 0.6545611619949341),
#  ('turkey', 0.6506675481796265),
#  ('bulgaria', 0.6442033052444458),
#  ('romania', 0.6315340995788574),
#  ('estonia', 0.6312719583511353),
#  ('portugal', 0.6253728866577148),
#  ('cyprus', 0.625159502029419),
#  ('macedonia', 0.6197174191474915),
#  ('olympics', 0.6187255382537842)]

# %% [markdown]
# However, we should not forget that these models are trained in human generated language. Meaning that societal and demographic biases are inevitable. In the following example you will witness these kinds of biases in the final output.
#
# Fortunately, extensive research has been done to tackle this issue trying to de-bias the embeddings models. More regarding this topic will be covered in Week 10 when we will talk about Ethics in NLP regarding Toxicity, Bias and Fairness.
#
# **Analogy C:**  `Doctor` - `Man` + `Woman` ~ `Nurse`

# %%
glove_vectors.most_similar(
    positive=['doctor', 'woman'],
    negative=['man'],
    topn=10
)
# Out:
# [('nurse', 0.7735227942466736),
#  ('physician', 0.7189430594444275),
#  ('doctors', 0.6824328303337097),
#  ('patient', 0.6750682592391968),
#  ('dentist', 0.6726033091545105),
#  ('pregnant', 0.6642459630966187),
#  ('medical', 0.6520448923110962),
#  ('nursing', 0.645348072052002),
#  ('mother', 0.63933265209198),
#  ('hospital', 0.6387495994567871)]

# %% [markdown]
# ### 2.3 Evaluate different models with SimLex
#
# In this part of the exercise, we will evaluate the syntactic concreteness of the created vectors using their similarity. For this task, we will use the SimLex999 dataset which is a human-annotated dataset regarding the similarity of concepts of words.
#
# - 📄 Paper: https://aclanthology.org/J15-4004.pdf
# - 👾 More about the task: https://fh295.github.io/simlex.html
#
# > - Download the data from [here](https://fh295.github.io/SimLex-999.zip)
# > - Unzip the file and put the corresponding folder with the dataset in the same dir as this notebook
#
# SimLex-999 is a gold standard resource for the evaluation of models that learn the meaning of words and concepts. SimLex-999 provides a way of measuring how well models capture similarity, rather than relatedness or association.
#
# #### Dataset:
# SimLex-999.txt is a tab-separated plaintext file, where rows correspond to concept pairs and columns correspond to the properties of each pair.
#
# |Column | Description |
# |-------|:-------------|
# |word1| The first concept in the pair.|
# |word2| The second concept in the pair. Note that the order is only relevant to the column Assoc(USF). These values (free association scores) are asymmetric. All other values are symmetric properties independent of the ordering word1, word2.|
# |POS| The majority part-of-speech of the concept words, as determined by occurrence in the POS-tagged British National Corpus. Only pairs of matching POS are included in SimLex-999.|
# |SimLex999 | The SimLex999 similarity rating. Note that average annotator scores have been (linearly) mapped from the range [0,6] to the range [0,10] to match other datasets such as WordSim-353. |
# |conc(w1)| The concreteness rating of word1 on a scale of 1-7. Taken from the University of South Florida Free Association Norms database. |
# |conc(w2)| The concreteness rating of word2 on a scale of 1-7. Taken from the University of South Florida Free Association Norms database.|
# |concQ| The quartile the pair occupies based on the two concreteness ratings. Used for some analyses in the above paper.|
# |Assoc(USF)| The strength of free association from word1 to word2. Values are taken from the University of South Florida Free Association Dataset.|
# |SimAssoc333| Binary indicator of whether the pair is one of the 333 most associated in the dataset (according to Assoc(USF)). This subset of SimLex999 is often the hardest for computational models to capture because the noise from high association can confound the similarity rating. See the paper for more details.|
# |SD(SimLex)| The standard deviation of annotator scores when rating this pair. Low values indicate good agreement between the 15+ annotators on the similarity value SimLex999. Higher scores indicate less certainty. |

# %% [markdown]
# We will be using the **`SimLex999` similarity column** to evaluate our word embeddings on this dataset. We will select the top 50 most similar pairs according to simlex999 column which a score from 0 to 10 regarding the similarities of the two words (columns: word1, word2) and it has been annotated by humans. On this subset of data, we will find the similarity score of the two words using our two pre-trained embedding models (Word2Vec, GloVe).

# %%
# read data
simlex = pd.read_csv('SimLex-999/SimLex-999.txt', delimiter='\t')
simlex = simlex[['word1', 'word2', 'SimLex999']]
simlex.head()
# Out:
#    word1        word2  SimLex999
# 0    old          new       1.58
# 1  smart  intelligent       9.20
# 2   hard    difficult       8.77
# 3  happy     cheerful       9.55
# 4   hard         easy       0.95

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Print the min, avg and max values of SimLex999 score.
#
# </div>

# %%
print(simlex.SimLex999.describe())
# Out:
# count    999.000000
# mean       4.561572
# std        2.614663
# min        0.230000
# 25%        2.380000
# 50%        4.670000
# 75%        6.750000
# max        9.800000
# Name: SimLex999, dtype: float64

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Select the top 50 pairs with the highest SimLex similarity score.
# </div>

# %%
# select a subset of word-pairs with the highest similarity score given by annotators
simlex_similar_pairs = simlex.sort_values(by="SimLex999", ascending=False).head(50)
print(simlex_similar_pairs[["word1", "word2", "SimLex999"]])
# Out:
#            word1        word2  SimLex999
# 782       vanish    disappear       9.80
# 22         quick        rapid       9.70
# 205      creator        maker       9.62
# 8         stupid         dumb       9.58
# 16        insane        crazy       9.57
# 3          happy     cheerful       9.55
# 42         large          big       9.55
# 140          cow       cattle       9.52
# 134         area       region       9.47
# 18         large         huge       9.47
# 28        simple         easy       9.40
# 71       bizarre      strange       9.37
# 121      student        pupil       9.35
# 234     attorney       lawyer       9.35
# 781        occur       happen       9.32
# 162      hallway     corridor       9.28
# 799       inform       notify       9.25
# 128      teacher   instructor       9.25
# 34         weird          odd       9.20
# 143         taxi          cab       9.20
# 1          smart  intelligent       9.20
# 65        scarce         rare       9.17
# 529      drizzle         rain       9.17
# 6          happy         glad       9.17
# 786      protect       defend       9.13
# 784        plead          beg       9.08
# 298     boundary       border       9.08
# 885      declare     announce       9.08
# 442    adversary     opponent       9.05
# 165          cop      sheriff       9.05
# 385  corporation     business       9.02
# 352         pact    agreement       9.02
# 25       strange          odd       9.02
# 236     business      company       9.02
# 186      victory      triumph       8.98
# 59     essential    necessary       8.97
# 265    abundance       plenty       8.97
# 9          weird      strange       8.93
# 370    physician       doctor       8.88
# 592      journey         trip       8.88
# 541         task          job       8.87
# 129        movie         film       8.87
# 816       decide       choose       8.87
# 819         roam       wander       8.83
# 285        shore        coast       8.83
# 839      acquire          get       8.82
# 62       crucial    important       8.82
# 945  contemplate        think       8.82
# 120       friend        buddy       8.78
# 303      heroine         hero       8.78

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** For each word pair from `simlex_similar_pairs`, compute the similarity between the GloVe embeddings (also Word2Vec embeddings) of the words.
# - 💻 **API:** You can use Gensim's `.similarity` function.
#
# </div>

# %%
# computes the similarities of each pair using each word embedding model
# compute model similarity per pair
simlex_similar_pairs["similarity_glove"] = simlex_similar_pairs.apply(
    lambda r: glove_vectors.similarity(r["word1"], r["word2"]),
    axis=1
)

simlex_similar_pairs["similarity_w2v"] = simlex_similar_pairs.apply(
    lambda r: w2v_vectors.similarity(r["word1"], r["word2"]),
    axis=1
)

# %%
print(simlex_similar_pairs)

similarities= simlex_similar_pairs
# Out:
#            word1        word2  SimLex999  glove_similarity  similarity_glove  \
# 782       vanish    disappear       9.80          0.881494          0.881494
# 22         quick        rapid       9.70          0.561225          0.561225
# 205      creator        maker       9.62          0.243845          0.243845
# 8         stupid         dumb       9.58          0.836065          0.836065
# 16        insane        crazy       9.57          0.591737          0.591737
# 3          happy     cheerful       9.55          0.545994          0.545994
# 42         large          big       9.55          0.708206          0.708206
# 140          cow       cattle       9.52          0.719291          0.719291
# 134         area       region       9.47          0.745878          0.745878
# 18         large         huge       9.47          0.808727          0.808727
# 28        simple         easy       9.40          0.764939          0.764939
# 71       bizarre      strange       9.37          0.814458          0.814458
# 121      student        pupil       9.35          0.486802          0.486802
# 234     attorney       lawyer       9.35          0.848366          0.848366
# 781        occur       happen       9.32          0.635600          0.635600
# 162      hallway     corridor       9.28          0.361724          0.361724
# 799       inform       notify       9.25          0.783296          0.783296
# 128      teacher   instructor       9.25          0.707712          0.707712
# 34         weird          odd       9.20          0.755024          0.755024
# 143         taxi          cab       9.20          0.755680          0.755680
# 1          smart  intelligent       9.20          0.755273          0.755273
# 65        scarce         rare       9.17          0.379119          0.379119
# 529      drizzle         rain       9.17          0.516915          0.516915
# 6          happy         glad       9.17          0.783336          0.783336
# 786      protect       defend       9.13          0.734868          0.734868
# 784        plead          beg       9.08          0.322985          0.322985
# 298     boundary       border       9.08          0.542754          0.542754
# 885      declare     announce       9.08          0.674811          0.674811
# 442    adversary     opponent       9.05          0.560470          0.560470
# 165          cop      sheriff       9.05          0.462331          0.462331
# 385  corporation     business       9.02          0.578707          0.578707
# 352         pact    agreement       9.02          0.839256          0.839256
# 25       strange          odd       9.02          0.815649          0.815649
# 236     business      company       9.02          0.773225          0.773225
# 186      victory      triumph       8.98          0.843505          0.843505
# 59     essential    necessary       8.97          0.785108          0.785108
# 265    abundance       plenty       8.97          0.466622          0.466622
# 9          weird      strange       8.93          0.824736          0.824736
# 370    physician       doctor       8.88          0.767324          0.767324
# 592      journey         trip       8.88          0.728900          0.728900
# 541         task          job       8.87          0.584861          0.584861
# 129        movie         film       8.87          0.905512          0.905512
# 816       decide       choose       8.87          0.789411          0.789411
# 819         roam       wander       8.83          0.761851          0.761851
# 285        shore        coast       8.83          0.700027          0.700027
# 839      acquire          get       8.82          0.437896          0.437896
# 62       crucial    important       8.82          0.779383          0.779383
# 945  contemplate        think       8.82          0.404147          0.404147
# 120       friend        buddy       8.78          0.588303          0.588303
# 303      heroine         hero       8.78          0.636298          0.636298
#
#      similarity_word2vec  similarity_w2v
# 782             0.900423        0.900423
# 22              0.497791        0.497791
# 205             0.260506        0.260506
# 8               0.817314        0.817314
# 16              0.733904        0.733904
# 3               0.383774        0.383774
# 42              0.556148        0.556148
# 140             0.631946        0.631946
# 134             0.568542        0.568542
# 18              0.658917        0.658917
# 28              0.599030        0.599030
# 71              0.737859        0.737859
# 121             0.512326        0.512326
# 234             0.820451        0.820451
# 781             0.660862        0.660862
# 162             0.321859        0.321859
# 799             0.671638        0.671638
# 128             0.525328        0.525328
# 34              0.638152        0.638152
# 143             0.751056        0.751056
# 1               0.649528        0.649528
# 65              0.323838        0.323838
# 529             0.698552        0.698552
# 6               0.740889        0.740889
# 786             0.600040        0.600040
# 784             0.510015        0.510015
# 298             0.386058        0.386058
# 885             0.399056        0.399056
# 442             0.569245        0.569245
# 165             0.332442        0.332442
# 385             0.415702        0.415702
# 352             0.736620        0.736620
# 25              0.730743        0.730743
# 236             0.519200        0.519200
# 186             0.828833        0.828833
# 59              0.625483        0.625483
# 265             0.481490        0.481490
# 9               0.816458        0.816458
# 370             0.780602        0.780602
# 592             0.616494        0.616494
# 541             0.385353        0.385353
# 129             0.867677        0.867677
# 816             0.610188        0.610188
# 819             0.670539        0.670539
# 285             0.508367        0.508367
# 839             0.206183        0.206183
# 62              0.707632        0.707632
# 945             0.344959        0.344959
# 120             0.697249        0.697249
# 303             0.521106        0.521106

# %%
# plots the distribution of similarity scores for each model
sims_w2v = similarities[['similarity_w2v']].rename(columns = {'similarity_w2v': 'similarity'})
sims_w2v['model'] = 'Word2vec'
sims_glove = similarities[['similarity_glove']].rename(columns = {'similarity_glove': 'similarity'})
sims_glove['model'] = 'GloVe'
to_plot = pd.concat([sims_w2v, sims_glove], ignore_index=True)
sns.displot(to_plot, x="similarity", hue="model", kind="kde")
plt.show()

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Extra quiz:
# Think about which model seems to perform better on these high-similarity examples and why based on your knowledge of how the embedding models have been trained.
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# <a id="3"></a>
# ## 3. TASK C: Sentiment analysis of movie reviews
#
# For this part, we will be using only the GloVe pre-trained embeddings.
#
# **Data:** We will build a sentiment classification model using the IMDB review dataset.
#
# > - Download the dataset [here](https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews?phase=FinishSSORegistration). You may have to sign in / sign up on Kaggle.
# > - Save the .csv file in the same dir as this notebook.
#
# The IMDB dataset has 50K movie reviews for natural language processing or Text analytics. This is a dataset for binary sentiment classification containing substantially more data than previous benchmark datasets. We provide a set of 25,000 highly polar movie reviews for training and 25,000 for testing.
#
# The goal is to predict if a review is positive or negative using a classification (potentiall deep learning) algorithm.
#
# For more dataset information, please go through the following link,
# http://ai.stanford.edu/~amaas/data/sentiment/

# %% [markdown]
# ![IMDB-reviews-dataset-stats.png](attachment:IMDB-reviews-dataset-stats.png)

# %% [markdown]
# ### 3.1 Dataset exploration

# %%
#read dataset
movie_reviews = pd.read_csv('IMDB Dataset.csv')
print(movie_reviews.head())
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print('Number of movie reviews: {}'.format(len(movie_reviews)))
classes = movie_reviews['sentiment'].unique()
print('Number of classes: {} with values: {}'.format(len(classes), classes))
# Out:
# Number of movie reviews: 50000
# Number of classes: 2 with values: ['positive' 'negative']

# %%
# class distribution
positive = len(movie_reviews[movie_reviews['sentiment']=='positive'])
negative = len(movie_reviews[movie_reviews['sentiment']=='negative'])

print('# of positive samples: {}'.format(positive))
print('# of negative samples: {}'.format(negative))

sns.set_theme(rc={'figure.figsize':(5.7,5.27)})
sns.countplot(x=movie_reviews['sentiment'])
plt.show()
# Out:
# # of positive samples: 25000
# # of negative samples: 25000

# %% [markdown]
# ### 3.2 Data preprocessing
#
# To build our classifier, we will leverage the pre-trained word embeddings (GloVe). Going from word embeddings to sentence vectors, we will need to find a way to take into account the embeddings of all the words each review contains. We will apply 2 techniques to do so: average and max pooling.
#
# We will perform the following preprocessing steps:
# - Change the classes from str (negative, positive) to binary `(0, 1)`.
# - Get word embeddings and calculate the sentence vectors with both max and avg pooling.
# - Create a `pytorch.Dataset` instance of the IMDB data.

# %% [markdown]
# #### From class names to binary

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Change the classe names from str (negative, positive) to binary `(0, 1)` and add it as a new column to the exising dataframe.
#
# </div>

# %%
# classes to binary
movie_reviews['target'] = movie_reviews['sentiment'].apply(lambda x: 1 if x == 'positive' else 0)

# %% [markdown]
# #### From word embeddings to review embeddings

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** For each review in the dataset, calculate the review vector by pooling from the review's word embeddings. Implement both max and avg pooling.
# - 💻 **API:** You can use numpy functions to manipulate the arrays. For review tokenization you can use `gensim.utils.tokenize` function.
#
# </div>

# %%
# apply embedding model to the words of the reviews and then perform pooling
sentence = movie_reviews['review'][0]
tokens = list(tokenize(sentence))

movie_reviews['sentence'] = movie_reviews['review'].apply(lambda x: list(tokenize(x)))

movie_reviews['vectors_max'] = movie_reviews['sentence'].apply(lambda x: np.max([w2v_vectors[word] for word in x if word in w2v_vectors], axis=0) if len(x) > 0 else np.zeros(w2v_vectors.vector_size))

movie_reviews['vectors_avg'] = movie_reviews['sentence'].apply(lambda x: np.mean([w2v_vectors[word] for word in x if word in w2v_vectors], axis=0) if len(x) > 0 else np.zeros(w2v_vectors.vector_size))


print(movie_reviews.head())
    
# review_vectors_max = np.array(...
# review_vectors_avg = np.array(...
# Out:
#                                               review sentiment  target  \
# 0  One of the other reviewers has mentioned that ...  positive       1
# 1  A wonderful little production. <br /><br />The...  positive       1
# 2  I thought this was a wonderful way to spend ti...  positive       1
# 3  Basically there's a family where a little boy ...  negative       0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive       1
#
#                                             sentence  \
# 0  [One, of, the, other, reviewers, has, mentione...
# 1  [A, wonderful, little, production, br, br, The...
# 2  [I, thought, this, was, a, wonderful, way, to,...
# 3  [Basically, there, s, a, family, where, a, lit...
# 4  [Petter, Mattei, s, Love, in, the, Time, of, M...
#
#                                          vectors_max  \
# 0  [0.60546875, 0.3984375, 0.51953125, 0.51171875...
# 1  [0.5546875, 0.36914062, 0.34179688, 0.5234375,...
# 2  [0.36914062, 0.55859375, 0.31445312, 0.6210937...
# 3  [0.36132812, 0.29296875, 0.23144531, 0.4042968...
# 4  [0.375, 0.38085938, 0.28710938, 0.3671875, 0.3...
#
#                                          vectors_avg
# 0  [0.039660893, 0.03537921, 0.03965262, 0.079582...
# 1  [0.050480712, 0.059323672, 0.007543822, 0.0569...
# 2  [0.031370874, 0.04233005, 0.017595528, 0.08539...
# 3  [0.052600704, 0.035269745, 0.006369725, 0.0880...
# 4  [0.038457666, 0.035824843, 0.020496422, 0.0576...

# %% [markdown]
# #### PyTorch Dataset class for the imported data

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create a PyTorch Dataset class with the input data. Instantiate this class with the input data.
# - 💻 **API:** You can use `torch.utils.data.Dataset` class.
#
# </div>

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class IMDBreviews(Dataset):
    def __init__(self, movie_reviews):
        self.x = torch.tensor(
            np.stack(movie_reviews["vectors_avg"].to_numpy()),
            dtype=torch.float32
        )
        self.y = torch.tensor(
            movie_reviews["target"].to_numpy(),
            dtype=torch.long
        )

    def __len__(self):
        return len(self.y)

    def __getitem__(self, it):
        return self.x[it], self.y[it]

dataset = IMDBreviews(movie_reviews)
print(dataset.x.shape, dataset.y.shape)
# Out:
# torch.Size([50000, 300]) torch.Size([50000])

# %%
# print tensors for sanity check
print('Total samples {} with sentence embedding size: {}'.format(dataset.x.shape[0], dataset.x.shape[1]))
# Out:
# Total samples 50000 with sentence embedding size: 300

# %% [markdown]
# #### Splitting dataset to train and test subsets

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Split the dataset into train and test sets (80-20% splits).
# - 💻 **API:** You can use `torch.utils.data.random_split` function.
#
# </div>

# %%
# split to train and test sets
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train, test = torch.utils.data.random_split(dataset, [train_size, test_size])

# %%
print('Train size: {}'.format(len(train)))
print('Test size: {}'.format(len(test)))
# Out:
# Train size: 40000
# Test size: 10000

# %% [markdown]
# ### 3.3 Train & evaluate a classifier on the movie reviews
#
# Once we have preprocessed the data, we will create the training and evaluation pipelines.

# %% [markdown]
# #### PyTorch Module class for model setup

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create a PyTorch model class. The architecture of the model can be as simple as a Linear layer along with a sigmoid activation function, or a more complicated deep architecture. Play around with different settings and architectures.
# - 💻 **API:** You can use `torch.nn.Module` class.
#
# </div>

# %%
# create a pytorch nn.Module class for the simple logistic regression model
class SentimentAnalysisModel(nn.Module):

    def __init__(self, input_size):
        super(SentimentAnalysisModel, self).__init__()
        self.LR = nn.Linear(input_size, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return self.sigmoid(self.LR(x))

# %%
input_size = dataset.x.shape[1]
model = SentimentAnalysisModel(input_size)
model
# Out:
# SentimentAnalysisModel(
#   (LR): Linear(in_features=300, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')
# Out:
# The model has 301 trainable parameters

# %% [markdown]
# #### Pytorch Data loader class for dataset batching

# %%
# create data loader
BATCH_SIZE = 64
train_loader = DataLoader(train, batch_size=BATCH_SIZE, shuffle=True)
test_loader= DataLoader(test, batch_size=BATCH_SIZE)

# %% [markdown]
# #### Training the model

# %%
# Construct a loss function and an optimizer. The call to model.parameters()
# in the SGD constructor will contain the learnable parameters of the two
# nn.Linear modules which are members of the model.
from torch import optim
criterion = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=1e-1)

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Create the training loop: for each epoch, do the forward pass, compute the loss and do the backward propagation.
# - 💻 **API:** Check the official API for the [training process](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#train-the-network).
#
# </div>

# %%
# Training loop
model.train()
for epoch in range(100):
    epoch_loss = 0
    for i, data in enumerate(train_loader, 0):
        x,y = data
        
        # Forward pass: Compute predicted y by passing x to the model
        pred_y = model(x)

        
        # Compute loss
        y = y.float().squeeze()
        pred_y = pred_y.squeeze()
        loss = criterion(pred_y, y)
        
        # Perform a backward pass, and update the weights.
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item()
    
    print(f'Epoch {epoch + 1} | Loss: {(epoch_loss / len(train_loader)):.4f}')
# Out:
# Epoch 1 | Loss: 0.6840
# Epoch 2 | Loss: 0.6664
# Epoch 3 | Loss: 0.6513
# Epoch 4 | Loss: 0.6383
# Epoch 5 | Loss: 0.6269
# Epoch 6 | Loss: 0.6166
# Epoch 7 | Loss: 0.6073
# Epoch 8 | Loss: 0.5988
# Epoch 9 | Loss: 0.5910
# Epoch 10 | Loss: 0.5839
# Epoch 11 | Loss: 0.5771
# Epoch 12 | Loss: 0.5707
# Epoch 13 | Loss: 0.5648
# Epoch 14 | Loss: 0.5594
# Epoch 15 | Loss: 0.5541
# Epoch 16 | Loss: 0.5490
# Epoch 17 | Loss: 0.5444
# Epoch 18 | Loss: 0.5399
# Epoch 19 | Loss: 0.5356
# Epoch 20 | Loss: 0.5316
# Epoch 21 | Loss: 0.5277
# Epoch 22 | Loss: 0.5240
# Epoch 23 | Loss: 0.5204
# Epoch 24 | Loss: 0.5171
# Epoch 25 | Loss: 0.5138
# Epoch 26 | Loss: 0.5107
# Epoch 27 | Loss: 0.5077
# Epoch 28 | Loss: 0.5048
# Epoch 29 | Loss: 0.5020
# Epoch 30 | Loss: 0.4994
# Epoch 31 | Loss: 0.4968
# Epoch 32 | Loss: 0.4943
# Epoch 33 | Loss: 0.4919
# Epoch 34 | Loss: 0.4896
# Epoch 35 | Loss: 0.4874
# Epoch 36 | Loss: 0.4852
# Epoch 37 | Loss: 0.4831
# Epoch 38 | Loss: 0.4811
# Epoch 39 | Loss: 0.4792
# Epoch 40 | Loss: 0.4772
# Epoch 41 | Loss: 0.4754
# Epoch 42 | Loss: 0.4736
# Epoch 43 | Loss: 0.4719
# Epoch 44 | Loss: 0.4702
# Epoch 45 | Loss: 0.4686
# Epoch 46 | Loss: 0.4669
# Epoch 47 | Loss: 0.4654
# Epoch 48 | Loss: 0.4639
# Epoch 49 | Loss: 0.4624
# Epoch 50 | Loss: 0.4610
# Epoch 51 | Loss: 0.4596
# Epoch 52 | Loss: 0.4583
# Epoch 53 | Loss: 0.4569
# Epoch 54 | Loss: 0.4556
# Epoch 55 | Loss: 0.4543
# Epoch 56 | Loss: 0.4530
# Epoch 57 | Loss: 0.4519
# Epoch 58 | Loss: 0.4507
# Epoch 59 | Loss: 0.4496
# Epoch 60 | Loss: 0.4485
# Epoch 61 | Loss: 0.4473
# Epoch 62 | Loss: 0.4462
# Epoch 63 | Loss: 0.4452
# Epoch 64 | Loss: 0.4441
# Epoch 65 | Loss: 0.4432
# Epoch 66 | Loss: 0.4422
# Epoch 67 | Loss: 0.4412
# Epoch 68 | Loss: 0.4402
# Epoch 69 | Loss: 0.4393
# Epoch 70 | Loss: 0.4384
# Epoch 71 | Loss: 0.4375
# Epoch 72 | Loss: 0.4366
# Epoch 73 | Loss: 0.4357
# Epoch 74 | Loss: 0.4349
# Epoch 75 | Loss: 0.4340
# Epoch 76 | Loss: 0.4332
# Epoch 77 | Loss: 0.4324
# Epoch 78 | Loss: 0.4316
# Epoch 79 | Loss: 0.4309
# Epoch 80 | Loss: 0.4301
# Epoch 81 | Loss: 0.4293
# Epoch 82 | Loss: 0.4286
# Epoch 83 | Loss: 0.4278
# Epoch 84 | Loss: 0.4272
# Epoch 85 | Loss: 0.4265
# Epoch 86 | Loss: 0.4258
# Epoch 87 | Loss: 0.4251
# Epoch 88 | Loss: 0.4244
# Epoch 89 | Loss: 0.4238
# Epoch 90 | Loss: 0.4231
# Epoch 91 | Loss: 0.4225
# Epoch 92 | Loss: 0.4218
# Epoch 93 | Loss: 0.4212
# Epoch 94 | Loss: 0.4206
# Epoch 95 | Loss: 0.4199
# Epoch 96 | Loss: 0.4194
# Epoch 97 | Loss: 0.4189
# Epoch 98 | Loss: 0.4183
# Epoch 99 | Loss: 0.4177
# Epoch 100 | Loss: 0.4172

# %% [markdown]
# #### Inference on the test set

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid #03befc;background-color:#F3F3F3;color:#424242;">
#
# - 🎯 **Goal:** Evaluate your model on the test set: for each batch of data, do the forward pass and compute the loss and the accuracy score.
# - 💻 **API:** Check the official API for the [testing process](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#test-the-network-on-the-test-data).
#
# </div>

# %%
from torchmetrics.classification import BinaryAccuracy

batch_loss = 0.0
metric = BinaryAccuracy()

model.eval()
with torch.no_grad():
    for x, y in test_loader:
        pred_y = model(x).squeeze(1)   # logits or probs depending on model
        y = y.float()

        loss = criterion(pred_y, y)
        batch_loss += loss.item()

        metric.update(pred_y, y.int())  # if using BCEWithLogitsLoss, BinaryAccuracy handles logits

test_loss = batch_loss / len(test_loader)
test_acc = metric.compute().item()

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Acc: {test_acc*100:.2f}%")
# Out:
# Test Loss: 0.4126
# Test Acc: 83.30%

# %% [markdown]
# <div style="padding:8px 0 8px 15px;border-left:3px solid gray;background-color:#F3F3F3;color:#424242;">
#
# #### Extra quiz:
# Play around with different settings (e.g. learning rate, batch size, epochs) and different architectures. Additionally try different pooling methods. Think how your design choices affect model performance on both train and test sets.
#
# </div>

# %% [markdown]
# ### 🎉 Congrats! You finished your first exercise session!
#
# Awesome work!
